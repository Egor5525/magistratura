# %% [markdown]
# Так как я не понял, должны быть значения рандомными или нет, я создал один массив нерандомный и один рандомный:

# %%
import numpy as np

# %%
regular_vector = np.linspace(0, 1, 12)[1:-1]
print(regular_vector)
# Out:
# [0.09090909 0.18181818 0.27272727 0.36363636 0.45454545 0.54545455
#  0.63636364 0.72727273 0.81818182 0.90909091]

# %% [markdown]
# Ровно не вышло

# %%
random_vector = np.random.uniform(0,1, 10)
print(random_vector)
# Out:
# [0.87801945 0.99038533 0.23631688 0.35552175 0.66390626 0.35420106
#  0.52181284 0.81974981 0.88289876 0.54887382]

# %% [markdown]
# Вариант рандомного вектора
